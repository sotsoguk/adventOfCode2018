# %%
with open('input.txt') as f:
    lines = f.readlines()

# %%
lines = [int(x.strip()) for x in lines]
sum(lines)
# Out:
# 578

# %%
lines
# Out:
# [5,
#  -11,
#  -1,
#  -16,
#  12,
#  9,
#  -15,
#  20,
#  4,
#  17,
#  -4,
#  -14,
#  6,
#  -17,
#  6,
#  -19,
#  -12,
#  17,
#  -6,
#  -18,
#  1,
#  15,
#  -14,
#  10,
#  -4,
#  -2,
#  5,
#  6,
#  8,
#  3,
#  17,
#  -9,
#  18,
#  -1,
#  17,
#  -15,
#  7,
#  -6,
#  -17,
#  -17,
#  19,
#  19,
#  -13,
#  18,
#  -15,
#  16,
#  7,
#  -10,
#  -5,
#  22,
#  8,
#  -13,
#  4,
#  3,
#  19,
#  17,
#  -19,
#  -1,
#  -11,
#  2,
#  1,
#  -13,
#  1,
#  3,
#  -14,
#  16,
#  -9,
#  19,
#  13,
#  -20,
#  6,
#  22,
#  10,
#  6,
#  15,
#  -13,
#  -13,
#  -8,
#  16,
#  20,
#  -5,
#  1,
#  7,
#  11,
#  -13,
#  5,
#  -16,
#  -2,
#  -4,
#  25,
#  -5,
#  -10,
#  -12,
#  -9,
#  16,
#  -2,
#  -19,
#  -3,
#  -12,
#  5,
#  17,
#  16,
#  11,
#  16,
#  10,
#  4,
#  3,
#  11,
#  -12,
#  19,
#  3,
#  17,
#  15,
#  -6,
#  -6,
#  -4,
#  3,
#  10,
#  8,
#  15,
#  -7,
#  13,
#  3,
#  6,
#  2,
#  16,
#  20,
#  3,
#  -11,
#  3,
#  -11,
#  12,
#  6,
#  3,
#  11,
#  5,
#  2,
#  12,
#  -4,
#  -2,
#  4,
#  3,
#  -4,
#  20,
# ...

# %%
oldFreq = false

# %%
partSums = [sum(lines[0:i]) for i,_ in enumerate(lines,1)]

# %%
seen = set()
seenTwice = False
def checkIfIn(i):
    if i in seen:
        print(i)
        seenTwice = True
        
    else:
        print(i)
        seen.add(i)
    return i
        
result = map(checkIfIn, partSums)

# %%
seen.add(5)

# %%
# Out:
# False

# %%
seen.
# Out:
# set()

# %%
seen.add(10)

# %%
seen.add(9)

# %%
7 in seen
# Out:
# False

# %%
partSums
# Out:
# [5,
#  -6,
#  -7,
#  -23,
#  -11,
#  -2,
#  -17,
#  3,
#  7,
#  24,
#  20,
#  6,
#  12,
#  -5,
#  1,
#  -18,
#  -30,
#  -13,
#  -19,
#  -37,
#  -36,
#  -21,
#  -35,
#  -25,
#  -29,
#  -31,
#  -26,
#  -20,
#  -12,
#  -9,
#  8,
#  -1,
#  17,
#  16,
#  33,
#  18,
#  25,
#  19,
#  2,
#  -15,
#  4,
#  23,
#  10,
#  28,
#  13,
#  29,
#  36,
#  26,
#  21,
#  43,
#  51,
#  38,
#  42,
#  45,
#  64,
#  81,
#  62,
#  61,
#  50,
#  52,
#  53,
#  40,
#  41,
#  44,
#  30,
#  46,
#  37,
#  56,
#  69,
#  49,
#  55,
#  77,
#  87,
#  93,
#  108,
#  95,
#  82,
#  74,
#  90,
#  110,
#  105,
#  106,
#  113,
#  124,
#  111,
#  116,
#  100,
#  98,
#  94,
#  119,
#  114,
#  104,
#  92,
#  83,
#  99,
#  97,
#  78,
#  75,
#  63,
#  68,
#  85,
#  101,
#  112,
#  128,
#  138,
#  142,
#  145,
#  156,
#  144,
#  163,
#  166,
#  183,
#  198,
#  192,
#  186,
#  182,
#  185,
#  195,
#  203,
#  218,
#  211,
#  224,
#  227,
#  233,
#  235,
#  251,
#  271,
#  274,
#  263,
#  266,
#  255,
#  267,
#  273,
#  276,
# ...

# %%
a=[1,2,3,4]
enumerate(a)

# %%
sum(a[0:2])
# Out:
# 3
